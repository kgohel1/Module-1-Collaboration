# %%
### 3.1 How many seconds are in an hour?
# Calculate using the number of seconds in a minute (60) multiplied by the number of minutes in an hour (60).
# Out:
#   Cell In[13], line 2
#     *Calculate using the number of seconds in a minute (60) multiplied by the number of minutes in an hour (60).
#                ^
# SyntaxError: invalid syntax

# %%
60 * 60
# Out:
# 3600

# %%
### 3.2 Assign the result from the previous task (seconds in an hour) to a variable called seconds_per_hour.

# %%
seconds_per_hour = 3600

# %%
### 3.3 How many seconds are in a day? Use your seconds_per_hour variable.

# %%
print(f'Total seconds in a day are {seconds_per_hour}.')
# Out:
# Total seconds in a day are 3600.

# %%
### 3.4 Calculate seconds per day again, but this time save result in a variable called seconds_per_day.

# %%
seconds_per_day = 60 * 60

# %%
### 3.5 Divide seconds_per_day by seconds_per_hour. Use floating-point (/) division.

# %%
seconds_per_day / seconds_per_hour
# Out:
# 1.0

# %%
### 3.6 Divide seconds_per_day by seconds_per_hour, using integer (//) division. Did this number agree with floating point value from the previous question, aside from the final .0?
